# %%
from rdkit import Chem
from rdkit.Chem import Draw

methane=Chem.MolFromSmiles("C")
methane

# %%
benezene=Chem.MolFromSmiles("c1ccccc1")
benezene

# %%
ethanol=Chem.MolFromSmiles("CCO")
ethanol

# %%
ethanol_h=Chem.AddHs(ethanol)
ethanol_h
